# %%
f = open('贷款app_list.txt','r',encoding='UTF-8')
l = list()
p = list()
for lines in f:
#for index in range(50001,keyword_total+1):
    #print("查看关键字：",index)
    keyword = lines.split('\t')[1]
    p.append(keyword)
    if keyword =="未知":
        continue
    l.append(keyword)
    #print(keyword)
len(l)
# Out:
# 8723

# %%
len(p)
# Out:
# 9003

# %%
s = []
f  = open('贷款app_list.txt',encoding='UTF-8') #由于我使用的pycharm已经设置完了路径，因此我直接写了文件名
i = 0
for lines in f:
    # query_list.append(line.replace('/','').replace('、','').replace(' ','').strip('\n'))
    print(lines)
    i += 1
    if i>100:
        break
    ls = lines.split('\t')[0]
    print(ls)
f.close()
# Out:
# package	name	class_rh
#
# package
# a.juboyi.com	9177	PDL
#
# a.juboyi.com
# cn.baifuwallet	猫猫钱包	PDL
#
# cn.baifuwallet
# cn.caiduoduo	财多多	PDL
#
# cn.caiduoduo
# cn.chenyiqiangui	哈呀贷	PDL
#
# cn.chenyiqiangui
# cn.feifeiwallet	天天钱包	PDL
#
# cn.feifeiwallet
# cn.feizhushidai	飞猪时代	PDL
#
# cn.feizhushidai
# cn.huajinbao	花金宝	PDL
#
# cn.huajinbao
# cn.hualebei	花了呗	PDL
#
# cn.hualebei
# cn.huasudai	花速贷	PDL
#
# cn.huasudai
# cn.jieyidian	借易点	PDL
#
# cn.jieyidian
# cn.jingangjieqian	金刚借钱	PDL
#
# cn.jingangjieqian
# cn.jinqianbao	无忧达人	PDL
#
# cn.jinqianbao
# cn.jinshabao	金沙宝	PDL
#
# cn.jinshabao
# cn.kuaixiangjin	快享金	PDL
#
# cn.kuaixiangjin
# cn.laidekuai	懒猫	PDL
#
# cn.laidekuai
# cn.lalabao	拉拉宝	PDL
#
# cn.lalabao
# cn.leishendai	雷神贷	PDL
#
# cn.leishendai
# cn.lianxin	花赢宝	PDL
#
# cn.lianxin
# cn.liuxingbao	流星宝	PDL
#
# cn.liuxingbao
# cn.mengniushidai	萌牛时代	PDL
#
# cn.mengniushidai
# cn.mirenhua	迷人花	PDL
#
# cn.mirenhua
# cn.moguqianbao	蘑菇钱包	PDL
#
# cn.moguqianbao
# cn.pettywallet	易管家	PDL
#
# ...

# %%
from urllib import parse
parse.quote('未向')
# Out:
# '%E6%9C%AA%E5%90%91'
